# %% [markdown]
# # NETFLIX MOVIE RECOMMENDATION PROJECT

# %% [markdown]
# **USING ECLET ALGOITHUM(ASSOCIATION RULE BASED LEARNING)**

# %% [markdown]
# YBI foundation Project
#
# Movie Recommendation system.
#
# Author: Rajat Kapoor
# email: rajat01kapoor@gmail.com

# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=72737b0c12e666010661eda43c5d5eaa218c148383b0f3a10729b220fbad7a6c
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
#if you need to mout the drive then use this code:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **IMPORTING LIBRARIES AND DATASET**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv("/content/Netflix Movie Recommendation Ec.csv" , header = None)

# for storing all this transcation we need the list

transactions = [] # created the empty list

# for adding in transaction we will use the for loop here
for i in range (1 , 7466):
  transactions.append([str(data_set.values[i,j]) for j in range(0,20)])

# %%
print(transactions)
# Out:
# [['The Shawshank Redemption', 'Fight Club', 'Pulp Fiction', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['The Godfather', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['The Godfather: Part II', 'Se7en', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['The Dark Knight', 'The Intouchables', "One Flew Over the Cuckoo's Nest", 'whole wheat Star Wars: Episode V - The Empire Strikes Back', 'Whiplash', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['12 Angry Men', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['Kanan Gill Comedy', 'The Lord of the Rings: The Return of the King', 'nan', 'nan', 'nan', 'nan'
# ...

# %% [markdown]
# **ECLET TRAINING ON DATASET**

# %%
# importing the libraries
from apyori import apriori

# we will initialize it
rules = apriori (transactions = transactions , min_support = 0.003 , min_confidence = 0.0003 , min_lift = 3 , min_length = 2 , max_length = 2 )

# %% [markdown]
# **VISUALIZING ALL THE RESULT**

# %% [markdown]
# ***RAW RESULT***

# %%
# we need to create the list of basket intteligence

result = list(rules)
result
# Out:
# [RelationRecord(items=frozenset({'Captain America', 'Black Panther'}), support=0.003348961821835231, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Captain America'}), confidence=0.0704225352112676, lift=5.153962993648163), OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Black Panther'}), confidence=0.2450980392156863, lift=5.153962993648164)]),
#  RelationRecord(items=frozenset({'Black Panther', 'Seven Samurai'}), support=0.004018754186202277, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Black Panther'}), items_add=frozenset({'Seven Samurai'}), confidence=0.08450704225352111, lift=3.777515391751707), OrderedStatistic(items_base=frozenset({'Seven Samurai'}), items_add=frozenset({'Black Panther'}), confidence=0.17964071856287422, lift=3.7775153917517073)]),
# ...

# %% [markdown]
# ***PROPER DISPLAY***

# %%
def inspect(result):
  Movie_1 = [tuple(result[2][0][0])[0] for result in result]
  Movie_2 = [tuple(result[2][0][1])[0] for result in result]
  support = [result[1] for result in result]
  return list(zip( Movie_1, Movie_2 , support))
resultsinDataFrame = pd.DataFrame(inspect (result) , columns = ["Movie 1" , "Movie 2" , "support"])

# %%
resultsinDataFrame
# Out:
#                      Movie 1                      Movie 2   support
# 0              Black Panther              Captain America  0.003349
# 1              Black Panther                Seven Samurai  0.004019
# 2                 Braveheart  Witness for the Prosecution  0.004287
# 3                  Capernaum                    Toy Story  0.003483
# 4   Comedy nights with Kapil              Game of thrones  0.003215
# 5   Comedy nights with Kapil            Kanan Gill Comedy  0.008038
# 6            Game of thrones                Prision Break  0.004555
# 7             Harry Potter 1               Harry Potter 2  0.005760
# 8             Harry Potter 1        The Lord of the rings  0.005090
# 9             Harry Potter 2        crimes of grindelwald  0.005760
# 10              Interstellar                    inception  0.015941
# 11   The Wolf of Wall Street                    inception  0.005358
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
# PRINTING IN TH ORDER
resultsinDataFrame.nlargest(n = 10, columns = 'support')
# Out:
#                      Movie 1                      Movie 2   support
# 10              Interstellar                    inception  0.015941
# 5   Comedy nights with Kapil            Kanan Gill Comedy  0.008038
# 7             Harry Potter 1               Harry Potter 2  0.005760
# 9             Harry Potter 2        crimes of grindelwald  0.005760
# 11   The Wolf of Wall Street                    inception  0.005358
# 8             Harry Potter 1        The Lord of the rings  0.005090
# 6            Game of thrones                Prision Break  0.004555
# 2                 Braveheart  Witness for the Prosecution  0.004287
# 1              Black Panther                Seven Samurai  0.004019
# 3                  Capernaum                    Toy Story  0.003483
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...
